# %%
import numpy as np
from src_OF.hamiltonians.PionlessEFT import *
from openfermion import *

# %%
x = jordan_wigner(PionlessEFT_Hamiltonian_1D(1,0,0,3))

# %%
x
# Out:
# (36+0j) [] +
# (-0.5+0j) [X0 Z1 Z2 Z3 X4] +
# (-0.5+0j) [Y0 Z1 Z2 Z3 Y4] +
# (-3+0j) [Z0] +
# (-0.5+0j) [X1 Z2 Z3 Z4 X5] +
# (-0.5+0j) [Y1 Z2 Z3 Z4 Y5] +
# (-3+0j) [Z1] +
# (-0.5+0j) [X2 Z3 Z4 Z5 X6] +
# (-0.5+0j) [Y2 Z3 Z4 Z5 Y6] +
# (-3+0j) [Z2] +
# (-0.5+0j) [X3 Z4 Z5 Z6 X7] +
# (-0.5+0j) [Y3 Z4 Z5 Z6 Y7] +
# (-3+0j) [Z3] +
# (-0.5+0j) [X4 Z5 Z6 Z7 X8] +
# (-0.5+0j) [Y4 Z5 Z6 Z7 Y8] +
# (-3+0j) [Z4] +
# (-0.5+0j) [X5 Z6 Z7 Z8 X9] +
# (-0.5+0j) [Y5 Z6 Z7 Z8 Y9] +
# (-3+0j) [Z5] +
# (-0.5+0j) [X6 Z7 Z8 Z9 X10] +
# (-0.5+0j) [Y6 Z7 Z8 Z9 Y10] +
# (-3+0j) [Z6] +
# (-0.5+0j) [X7 Z8 Z9 Z10 X11] +
# (-0.5+0j) [Y7 Z8 Z9 Z10 Y11] +
# (-3+0j) [Z7] +
# (-3+0j) [Z8] +
# (-3+0j) [Z9] +
# (-3+0j) [Z10] +
# (-3+0j) [Z11]
