# %%
import numpy as np
from src_OF.hamiltonians.PionlessEFT import *
from openfermion import QubitOperator,jordan_wigner, normal_ordered

# %%
x = jordan_wigner(PionlessEFT_Hamiltonian_1D(1,0,0,3))

# %%
normal_ordered(Annihilate(1)* Create(0) )
# Out:
# -1.0 [0^ 1]
